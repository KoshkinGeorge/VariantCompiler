# %% [markdown]
# ##Задание 1
# Выведите матрицу размера N * M, заполненную нулями
#
# **N = 2**
#
# **M = 5**

# %% [markdown]
# ##Задание 2
# Выведите матрицу размера N * M, у которой на главной диагонали стоят единицы
#
# **N = 15**
#
#
# **M = 5**

# %% [markdown]
# ##Задание 3
# Выведите диагональную матрицу размера N * N, у которой на диагонали расставлены числа от 1 до N в возрастающем порядке
#
# **N = 5**
